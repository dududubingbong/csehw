# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.io import wavfile
from numpy.linalg import svd
from scipy.stats.mstats import gmean
from matplotlib import rcParams
import scipy
import os
import sys
import glob
import pickle
from music21 import converter, instrument, note, chord, stream, duration
from keras import backend as K
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Embedding
from keras.layers import Concatenate
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Permute
from keras.layers import RepeatVector
from keras.layers import Multiply
from keras.layers import Lambda
from keras.optimizers import RMSprop
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
def create_network(notes_in, durations_in, n_notes, n_durations):
# def create_network(network_input, n_vocab):
#     model = Sequential()
#     model.add(LSTM(
#         512,
#         input_shape=(network_input.shape[1], network_input.shape[2]),
#         recurrent_dropout=0.3,
#         return_sequences=True
#     ))
    
#     ''' Your Code Here '''
#     #LSTM layer
#     model.add(LSTM(
#         512,
#         recurrent_dropout=0.3
#     ))
#     #batch normalization layer
#     #model.add(BatchNormalization())
#     #dropout layer
#     model.add(Dropout(0.3))
#     #fully connected layer
#     model.add(Dense(256))
#     #relu
#     model.add(Activation('relu'))
#     #batch normalization layer
#     model.add(BatchNorm())
#     #dropout layer
#     model.add(Dropout(0.3))
#     #fully connected layer
#     model.add(Dense(n_vocab)) #fix this one
#     #temperature
#     model.add(Lambda(lambda x: x/ .6))
#     #softmax
#     model.add(Activation('softmax'))
    
#     model.compile(loss="categorical_crossentropy", optimizer='adam')
#     #model.fit(network_input, epochs=50, verbose=0)
    
#     return model

    batch_size = 64
    embedding_dim = 100 #256
    rnn_units = 256
    x1 = Embedding(n_notes, embedding_dim)(notes_in)
    x2 = Embedding(n_durations, embedding_dim)(durations_in)

    x = Concatenate()([x1,x2])

    x = LSTM(rnn_units, return_sequences=True)(x)
    x = LSTM(rnn_units, return_sequences=True)(x)

    e = Dense(1, activation='tanh')(x)
    e = Reshape([-1])(e)

    alpha = Activation('softmax')(e)

    c = Permute([2,1])(RepeatVector(rnn_units)(alpha))
    c = Multiply()([x,c])
    c = Lambda(lambda xin: K.sum(xin, axis=1), output_shape=(rnn_units,))(c)

    notes_out = Dense(n_notes, activation = 'softmax', name = 'pitch')(c)
    durations_out = Dense(n_durations, activation = 'softmax', name='duration')(c)

    print(notes_out)
    model = Model([notes_in, durations_in], [notes_out, durations_out])

    att_model = Model([notes_in, durations_in], alpha)

    opti = RMSprop(learning_rate = 0.001)
    model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy'], optimizer=opti)
    
    return model, att_model


#create_network()

# %%
def get_notes():

    notes = []
    durations = []
    for file in glob.glob("midi/jazz2/*.mid"):
        try:
            midi = converter.parse(file)
            print("Parsing %s" % file)
            notes_to_parse = None
        #try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except Exception as inst:# file has notes in a flat structure
            notes_to_parse = midi.flat.notes
            print(inst)
            pass
        
        #print(notes_to_parse)
        for element in notes_to_parse:
            #print(element)
            if isinstance(element, note.Note):
                if element.isRest:
                    notes.append(str(element.name))
                    durations.append(element.duration.quarterLength)
                else:
                    notes.append(str(element.pitch))
                    durations.append(element.duration.quarterLength)
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))
                durations.append(element.duration.quarterLength)

    print("notes", notes)
    pickle.dump(notes, open('notes.p', 'wb'))
    pickle.dump(durations, open('durations.p', 'wb'))
    
    #print("notes: ", notes, "\n")
    return notes, durations


def prepare_sequences(notes, durations, n_vocab, d_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 32 

    pitchnames = sorted(set(item for item in notes))
    #print("pitchnames: ", pitchnames, "\n")
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    #print("note_to_int: ", note_to_int, "\n")
    
    durationnames = sorted(set(item for item in durations))
    #print("pitchnames: ", pitchnames, "\n")
    duration_to_int = dict((note, number) for number, note in enumerate(durationnames))
    #print("note_to_int: ", note_to_int, "\n")

    network_input = []
    network_output = []
    network_input2 = []
    network_output2 = []

    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        #print("sequence_in: ", sequence_in)
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        #print("network_input: ", network_input)
        network_output.append(note_to_int[sequence_out])
        
    for i in range(0, len(durations) - sequence_length, 1):
        sequence_in = durations[i:i + sequence_length]
        #print("sequence_in: ", sequence_in)
        sequence_out = durations[i + sequence_length]
        network_input2.append([duration_to_int[char] for char in sequence_in])
        #print("network_input: ", network_input)
        network_output2.append(duration_to_int[sequence_out])
        
    print("network input", network_input)  
    print("network input", network_input2)
    print("network output", network_output)
    print("network output", network_output2)

    n_patterns = len(network_input)
    n_patterns2 = len(network_input2)

    # reshape the input into a format compatible with LSTM layers
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    network_input2 = np.reshape(network_input2, (n_patterns2, sequence_length, 1))
    # normalize input
    network_input = network_input / float(n_vocab)
    network_input2 = network_input2 / float(n_vocab)

    network_output = np_utils.to_categorical(network_output)
    network_output2 = np_utils.to_categorical(network_output2)

    return (network_input, network_output, network_input2, network_output2)

# %%
notes, durations = get_notes()

n_vocab = len(set(notes))
d_vocab = len(set(durations))
# Out:
# Parsing midi/jazz2/OrnetteColeman_Chronology_FINAL.mid
# Parsing midi/jazz2/StanGetz_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_Stompin'AtTheSavoy_FINAL.mid
# Parsing midi/jazz2/KennyWheeler_DoubleVision_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_BopGoesToLeesel_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_SpeakNoEvil_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Walkin'_FINAL.mid
# Parsing midi/jazz2/ArtPepper_Stardust-2_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_Crosscurrent_FINAL.mid
# Parsing midi/jazz2/VonFreeman_PassItOn_FINAL.mid
# Parsing midi/jazz2/MilesDavis_SoWhat_FINAL.mid
# Parsing midi/jazz2/MiltJackson_AllTheThingsYouAre_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_AloneTogether_FINAL.mid
# Parsing midi/jazz2/PhilWoods_CrazyRhythm_FINAL.mid
# Parsing midi/jazz2/BennyCarter_SweetLorraine_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_BeginTheBeguine_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_Milestones_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_LineForLyons_FINAL.mid
# Parsing midi/jazz2/BobBerg_NatureOfTheBeast_FINAL.mid
# Parsing midi/jazz2/MiltJackson_SoftlyAsInAMorningSunrise_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Adam'sApple_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_SambaCantina-2_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_Avalon_FINAL.mid
# Parsing midi/jazz2/JoeLovano_ICan'tGetStarted_FINAL.mid
# Parsing midi/jazz2/SidneyBechet_Summertime_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_ANightInTunisia_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Bessie'sBlues_FINAL.mid
# Parsing midi/jazz2/KaiWinding_Tiny'sBlues_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_Airegin_FINAL.mid
# Parsing midi/jazz2/EricDolphy_OnGreenDolphinStreet_FINAL.mid
# Parsing midi/jazz2/LionelHampton_Avalon_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Airegin_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_SambaCantina-1_FINAL.mid
# Parsing midi/jazz2/LesterYoung_AfterTheatreJump_FINAL.mid
# Parsing midi/jazz2/PhilWoods_BeMyLove_FINAL.mid
# Parsing midi/jazz2/ChetBaker_JustFriends_FINAL.mid
# Parsing midi/jazz2/MiltJackson_Don'tGetAroundMuchAnymore_FINAL.mid
# Parsing midi/jazz2/LeeMorgan_TotemPole_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_Arjuna_FINAL.mid
# Parsing midi/jazz2/ChetBaker_IFallInLoveTooEasily_FINAL.mid
# Parsing midi/jazz2/MilesDavis_K.C.Blues_FINAL.mid
# Parsing midi/jazz2/LionelHampton_MemoriesOfYou_FINAL.mid
# Parsing midi/jazz2/BixBeiderbecke_RiverboatShuffle_FINAL.mid
# Parsing midi/jazz2/PhilWoods_CottonTail_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_TheNearnessOfYou_FINAL.mid
# Parsing midi/jazz2/ChetBaker_Let'sGetLost_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Orbits_FINAL.mid
# Parsing midi/jazz2/SteveColeman_PassItOn_FINAL.mid
# Parsing midi/jazz2/ArtPepper_BluesForBlanche_FINAL.mid
# Parsing midi/jazz2/EricDolphy_Aisha_FINAL.mid
# Parsing midi/jazz2/ArtPepper_Stardust-1_FINAL.mid
# Parsing midi/jazz2/MilesDavis_E.S.P._FINAL.mid
# Parsing midi/jazz2/JJJohnson_Teapot_FINAL.mid
# Parsing midi/jazz2/OrnetteColeman_BirdFood_FINAL.mid
# Parsing midi/jazz2/HankMobley_Doodlin'_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_I'veGotYouUnderMySkin_FINAL.mid
# Parsing midi/jazz2/BuckClayton_Dickie'sDream_FINAL.mid
# Parsing midi/jazz2/StanGetz_CrazyRhythm_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_GiantSteps-2_FINAL.mid
# Parsing midi/jazz2/ArtPepper_InAMellowTone_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_U.M.M.G._FINAL.mid
# Parsing midi/jazz2/BenWebster_MyIdeal_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_DolphinDance_FINAL.mid
# Parsing midi/jazz2/CharlieParker_YardbirdSuite_FINAL.mid
# Parsing midi/jazz2/LionelHampton_HighSociety_FINAL.mid
# Parsing midi/jazz2/CannonballAdderley_WorkSong_FINAL.mid
# Parsing midi/jazz2/HankMobley_SoulStation_FINAL.mid
# Parsing midi/jazz2/BenWebster_DidYouCallHerToday_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_DatDere_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_JoySpring_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_TheGirlFromEast9thStreet_FINAL.mid
# Parsing midi/jazz2/WayneShorter_DownUnder_FINAL.mid
# Parsing midi/jazz2/LesterYoung_D.B.Blues_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_Blue'nBoogie_FINAL.mid
# Parsing midi/jazz2/SidneyBechet_ReallyTheBlues_FINAL.mid
# Parsing midi/jazz2/PepperAdams_HowHighTheMoon_FINAL.mid
# Parsing midi/jazz2/NatAdderley_WorkSong_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_SecretLove_FINAL.mid
# Parsing midi/jazz2/ZootSims_KingDavid_FINAL.mid
# Parsing midi/jazz2/CharlieParker_ThrivingOnARiff_FINAL.mid
# Parsing midi/jazz2/KennyWheeler_SlippedAgain_FINAL.mid
# cannot handle ticks per frame: 144
# Parsing midi/jazz2/JohnColtrane_SoWhat_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_Rosewood_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_TenorMadness_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_BlueTrain_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/EricDolphy_DahomeyDance_FINAL.mid
# Parsing midi/jazz2/LeeMorgan_BlueTrain_FINAL.mid
# Parsing midi/jazz2/PhilWoods_Strollin'WithPam_FINAL.mid
# Parsing midi/jazz2/BennyCarter_IGotItBad_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_GiantSteps-1_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Nutty_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_Pablo'sStory_FINAL.mid
# Parsing midi/jazz2/JoshuaRedman_IGotYou_FINAL.mid
# Parsing midi/jazz2/MilesDavis_TuneUp_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Trane'sBlues_FINAL.mid
# Parsing midi/jazz2/BobBerg_Angles_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_Punjab_FINAL.mid
# Parsing midi/jazz2/HenryAllen_BabyWon'tYouPleaseComeHome_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_PopTune#1_FINAL.mid
# Parsing midi/jazz2/CharlieParker_DonnaLee_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_Perdido_FINAL.mid
# Parsing midi/jazz2/BenWebster_ByeByeBlackbird_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_HotterThanThat_FINAL.mid
# Parsing midi/jazz2/JoeLovano_Lonnie'sLament-1_FINAL.mid
# Parsing midi/jazz2/SteveTurre_IfIWereABell_FINAL.mid
# Parsing midi/jazz2/MiltJackson_Bag'sGroove_FINAL.mid
# Parsing midi/jazz2/KidOry_MuskratRamble_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_Steve'sBlues_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_DownUnder_FINAL.mid
# Parsing midi/jazz2/SteveLacy_Let'sCoolOne_FINAL.mid
# Parsing midi/jazz2/ArtPepper_Desafinado_FINAL.mid
# Parsing midi/jazz2/KennyGarrett_BrotherHubbard-1_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_Whispering_FINAL.mid
# Parsing midi/jazz2/JoeLovano_CentralParkWest_FINAL.mid
# Parsing midi/jazz2/ChetBaker_Two'sBlues_FINAL.mid
# Parsing midi/jazz2/BixBeiderbecke_Margie_FINAL.mid
# Parsing midi/jazz2/LesterYoung_SixCatsAndAPrince_FINAL.mid
# Parsing midi/jazz2/PhilWoods_OnASlowBoatToChina_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_TheEverywhereCalypso-2_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Agitation_FINAL.mid
# Parsing midi/jazz2/SonnyStitt_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/OrnetteColeman_Congeniality_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_BodyAndSoul_AlternateTake_FINAL.mid
# Parsing midi/jazz2/SteveColeman_Cross=Fade-1_FINAL.mid
# Parsing midi/jazz2/SteveTurre_Steve'sBlues_FINAL.mid
# Parsing midi/jazz2/PepperAdams_ANightInTunisia_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_Item1,D.I.T._FINAL.mid
# Parsing midi/jazz2/WoodyShaw_IfIWereABell_FINAL.mid
# Parsing midi/jazz2/ChuBerry_BodyAndSoul-2_FINAL.mid
# Parsing midi/jazz2/CannonballAdderley_SoWhat_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_TheEverywhereCalypso-1_FINAL.mid
# Parsing midi/jazz2/KennyDorham_Punjab_FINAL.mid
# Parsing midi/jazz2/DickieWells_AfterTheatreJump_FINAL.mid
# Parsing midi/jazz2/ChetBaker_You'dBeSoNiceToComeHomeTo_FINAL.mid
# Parsing midi/jazz2/PatMetheny_CabinFever_FINAL.mid
# Parsing midi/jazz2/JJJohnson_BluesInTheCloset_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_SongForBilbao_FINAL.mid
# Parsing midi/jazz2/SteveLacy_AloneTogether_FINAL.mid
# Parsing midi/jazz2/ChuBerry_BodyAndSoul-1_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Eighty=One_FINAL.mid
# Parsing midi/jazz2/SteveColeman_Cross=Fade-2_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_DoubleTalk_FINAL.mid
# Parsing midi/jazz2/KidOry_SavoyBlues_FINAL.mid
# Parsing midi/jazz2/DexterGordon_Cheesecake_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_TotemPole_FINAL.mid
# Parsing midi/jazz2/StanGetz_Insensatez_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_Anthropology_No1_FINAL.mid
# Parsing midi/jazz2/DexterGordon_StanleyTheSteamer_FINAL.mid
# Parsing midi/jazz2/DavidMurray_AskMeNow_FINAL.mid
# cannot handle ticks per frame: 144
# Parsing midi/jazz2/DavidLiebman_Pendulum_FINAL.mid
# Parsing midi/jazz2/HerbieHancock_Orbits_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Mr.P.C._FINAL.mid
# Parsing midi/jazz2/SteveColeman_TakeTheColtrane_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_Imagination_FINAL.mid
# Parsing midi/jazz2/JoeLovano_Work_FINAL.mid
# Parsing midi/jazz2/KennyGarrett_BrotherHubbard-2_FINAL.mid
# Parsing midi/jazz2/BuckClayton_DestinationK.C._FINAL.mid
# Parsing midi/jazz2/JoeHenderson_In'NOut-1_FINAL.mid
# Parsing midi/jazz2/HerbieHancock_Dolores_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_MeanToMe_FINAL.mid
# Parsing midi/jazz2/DonEllis_YouSteppedOutOfADream-2_FINAL.mid
# Parsing midi/jazz2/DonByas_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/OrnetteColeman_Ramblin'_FINAL.mid
# Parsing midi/jazz2/CharlieParker_OutOfNowhere_FINAL.mid
# Parsing midi/jazz2/SidneyBechet_LimehouseBlues_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_OurDelight_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_VierdBlues_FINAL.mid
# Parsing midi/jazz2/WarneMarsh_Wow-1_FINAL.mid
# Parsing midi/jazz2/DonByas_CognacBlues_FINAL.mid
# Parsing midi/jazz2/ZootSims_AllTheThingsYouAre_FINAL.mid
# Parsing midi/jazz2/BenWebster_WhereOrWhen_FINAL.mid
# Parsing midi/jazz2/KidOry_Who'sIt_FINAL.mid
# Parsing midi/jazz2/PatMetheny_MidnightVoyage_FINAL.mid
# Parsing midi/jazz2/HankMobley_LadyBird_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_GoodBait_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_Anthropology_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_Bunny_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_Stompin'AtTheSavoy_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_NoGreaterLove_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_NeverAlone_FINAL.mid
# Parsing midi/jazz2/GeorgeColeman_MaidenVoyage_FINAL.mid
# Parsing midi/jazz2/CharlieParker_StarEyes_FINAL.mid
# Parsing midi/jazz2/BixBeiderbecke_I'mComingVirginia_FINAL.mid
# Parsing midi/jazz2/JJJohnson_Elora_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_Anthropology_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_In'NOut-2_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_DeltaCityBlues_FINAL.mid
# Parsing midi/jazz2/LionelHampton_Runnin'Wild_FINAL.mid
# Parsing midi/jazz2/SonnyStitt_BluesInBe=Bop_FINAL.mid
# Parsing midi/jazz2/LesterYoung_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/DonEllis_YouSteppedOutOfADream-1_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_CherokeeII_FINAL.mid
# Parsing midi/jazz2/StanGetz_BluesInTheCloset_FINAL.mid
# Parsing midi/jazz2/RexStewart_Perdido_FINAL.mid
# Parsing midi/jazz2/BobBerg_IDidn'tKnowWhatTimeItWas_FINAL.mid
# Parsing midi/jazz2/LesterYoung_Dickie'sDream_FINAL.mid
# Parsing midi/jazz2/CharlieParker_K.C.Blues_FINAL.mid
# Parsing midi/jazz2/BobBerg_SecondSight_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Juju_FINAL.mid
# Parsing midi/jazz2/LeeMorgan_JustOneOfThoseThings_FINAL.mid
# Parsing midi/jazz2/ArtPepper_Anthropology_FINAL.mid
# Parsing midi/jazz2/SteveColeman_Segment_FINAL.mid
# Parsing midi/jazz2/WayneShorter_SpeakNoEvil_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Countdown_FINAL.mid
# Parsing midi/jazz2/DexterGordon_Montmartre_FINAL.mid
# Parsing midi/jazz2/DonByas_Be=Bop_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_Confirmation_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_SophisticatedLady_FINAL.mid
# Parsing midi/jazz2/CannonballAdderley_ThisHere_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Oleo_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Segment_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_BlueRondoALaTurk_FINAL.mid
# Parsing midi/jazz2/MilesDavis_BitchesBrew-1_FINAL.mid
# Parsing midi/jazz2/HerbieHancock_HandJive_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Ornithology_FINAL.mid
# Parsing midi/jazz2/KennyWheeler_PassItOn_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_Rumples_FINAL.mid
# Parsing midi/jazz2/DickieWells_Dickie'sDream_FINAL.mid
# Parsing midi/jazz2/BixBeiderbecke_SinginTheBlues_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_GoodBait_AlternateTake_FINAL.mid
# Parsing midi/jazz2/CharlieParker_HowDeepIsTheOcean_FINAL.mid
# Parsing midi/jazz2/KennyDorham_In'NOut_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_Playin'InTheYard-1_FINAL.mid
# Parsing midi/jazz2/JoeLovano_ConAlma_FINAL.mid
# Parsing midi/jazz2/SonnyStitt_Teapot_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_TheGasser-1_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Dolores_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_I'llRememberApril_FINAL.mid
# Parsing midi/jazz2/SteveColeman_SlippedAgain_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Steeplechase_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_MyFavoriteThings-2_FINAL.mid
# Parsing midi/jazz2/MiltJackson_What'sNew_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_ThisCan'tBeLove_FINAL.mid
# Parsing midi/jazz2/EricDolphy_245_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_Playin'InTheYard-2_FINAL.mid
# Parsing midi/jazz2/JoshuaRedman_BluesOnSunday_FINAL.mid
# Parsing midi/jazz2/KidOry_GutBucketBlues_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_MidnightVoyage_FINAL.mid
# Parsing midi/jazz2/JJJohnson_BlueMode_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_245_FINAL.mid
# Parsing midi/jazz2/LesterYoung_LesterLeapsIn_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_Rahsaan'sRun_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_JohnnyComeLately_FINAL.mid
# Parsing midi/jazz2/LesterYoung_DestinationK.C._FINAL.mid
# Parsing midi/jazz2/SonnyStitt_Elora_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_Undecided_FINAL.mid
# Parsing midi/jazz2/KidOry_GotNoBlues_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_GutBucketSteepy_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_TheGasser-2_FINAL.mid
# Parsing midi/jazz2/LeeMorgan_TheSidewinder_FINAL.mid
# Parsing midi/jazz2/KennyDorham_PrinceAlbert_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_MyFavoriteThings-1_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_ThereWillNeverBeAnotherYou_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_NatureBoy_FINAL.mid
# Parsing midi/jazz2/OrnetteColeman_Peace_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_Sandu_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_GotNoBlues_FINAL.mid
# Parsing midi/jazz2/CharlieParker_EmbraceableYou_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Don'tBlameMe_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_IMeanYou_FINAL.mid
# Parsing midi/jazz2/DickieWells_DestinationK.C._FINAL.mid
# Parsing midi/jazz2/JohnColtrane_BluesByFive_FINAL.mid
# Parsing midi/jazz2/KennyDorham_LadyBird_FINAL.mid
# Parsing midi/jazz2/WarneMarsh_Crosscurrent_FINAL.mid
# Parsing midi/jazz2/MilesDavis_BitchesBrew-2_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_OnceInAWhile_FINAL.mid
# Parsing midi/jazz2/JJJohnson_CrazyRhythm_FINAL.mid
# Parsing midi/jazz2/ChetBaker_ThereWillNeverBeAnotherYou-1_FINAL.mid
# Parsing midi/jazz2/SteveColeman_TheOracle-2_FINAL.mid
# Parsing midi/jazz2/JoeLovano_LittleWillieLeapsIn_FINAL.mid
# Parsing midi/jazz2/SteveLacy_Skippy_FINAL.mid
# Parsing midi/jazz2/DavidMurray_BluesForTwo-1_FINAL.mid
# Parsing midi/jazz2/JoshuaRedman_TearsInHeaven_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_ThreeLittleWords_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_ScrappleFromTheApple_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_HeebieJeebies_FINAL.mid
# cannot handle ticks per frame: 144
# Parsing midi/jazz2/PepperAdams_JustOneOfThoseThings_FINAL.mid
# Parsing midi/jazz2/KennyDorham_Serenity_FINAL.mid
# Parsing midi/jazz2/PhilWoods_HoneysuckleRose_FINAL.mid
# Parsing midi/jazz2/EricDolphy_Les_FINAL.mid
# Parsing midi/jazz2/JoshuaRedman_HomeFries_FINAL.mid
# Parsing midi/jazz2/DavidMurray_BodyAndSoul-2_FINAL.mid
# Parsing midi/jazz2/SteveLacy_EasyToLove_FINAL.mid
# Parsing midi/jazz2/BennyCarter_It'sAWonderfulWorld-2_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Trane'sBlues_FINAL.mid
# Parsing midi/jazz2/DonEllis_OutOfNowhere_FINAL.mid
# Parsing midi/jazz2/ZootSims_NightAndDay-2_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_26=2_FINAL.mid
# Parsing midi/jazz2/PatMetheny_AllTheThingsYouAre_FINAL.mid
# Parsing midi/jazz2/SteveLacy_Work_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_Alianca-1_FINAL.mid
# Parsing midi/jazz2/BuckClayton_AfterTheatreJump_FINAL.mid
# Parsing midi/jazz2/PaulDesmond_BossaAntigua_FINAL.mid
# Parsing midi/jazz2/DavidMurray_BodyAndSoul-1_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_CabinFever_FINAL.mid
# Parsing midi/jazz2/DonEllis_ILoveYou_FINAL.mid
# Parsing midi/jazz2/ZootSims_NightAndDay-1_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_CognacBlues_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_Nica'sDream_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_U.M.M.G._FINAL.mid
# Parsing midi/jazz2/PaulDesmond_Alianca-2_FINAL.mid
# Parsing midi/jazz2/BennyCarter_It'sAWonderfulWorld-1_FINAL.mid
# Parsing midi/jazz2/BobBerg_YouAndTheNightAndTheMusic_FINAL.mid
# Parsing midi/jazz2/DonByas_OutOfNowhere_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_Marshmallow_FINAL.mid
# Parsing midi/jazz2/HarryEdison_DidYouCallHerToday_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_It'sOnlyAPapermoon_FINAL.mid
# Parsing midi/jazz2/JohnAbercrombie_Ralph'sPianoWaltz_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_St.LouisBlues_FINAL.mid
# Parsing midi/jazz2/ChrisPotter_Togo_FINAL.mid
# Parsing midi/jazz2/SteveColeman_DoubleVision_FINAL.mid
# Parsing midi/jazz2/SonnyStitt_BlueMode_FINAL.mid
# Parsing midi/jazz2/RedGarland_Oleo_FINAL.mid
# Parsing midi/jazz2/SteveColeman_TheOracle-1_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_Runnin'Wild_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_Caravan_FINAL.mid
# Parsing midi/jazz2/ChetBaker_ThereWillNeverBeAnotherYou-2_FINAL.mid
# Parsing midi/jazz2/HankMobley_Remember_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_I'llRememberApril_AlternateTake2_FINAL.mid
# Parsing midi/jazz2/KennyDorham_BluesInBe=Bop_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_SoftlyAsInAMorningSunrise_FINAL.mid
# Parsing midi/jazz2/SidneyBechet_BabyWon'tYouPleaseComeHome_FINAL.mid
# Parsing midi/jazz2/DavidMurray_BluesForTwo-2_FINAL.mid
# Parsing midi/jazz2/PatMetheny_NothingPersonal_FINAL.mid
# Parsing midi/jazz2/JohnnyHodges_EarlyMorningRock_FINAL.mid
# Parsing midi/jazz2/MiltJackson_BemshaSwing_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_NakedSoul_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_HotHouse_FINAL.mid
# Parsing midi/jazz2/CharlieParker_ScrappleFromTheApple_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Eighty=One_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_JohnnyComeLately_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Footprints_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_BlueSeven-1_FINAL.mid
# Parsing midi/jazz2/DonByas_HarvardBlues-1_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_Nobody'sSweetheart_FINAL.mid
# Parsing midi/jazz2/CharlieShavers_LimehouseBlues_FINAL.mid
# Parsing midi/jazz2/NatAdderley_BohemiaAfterDark_FINAL.mid
# Parsing midi/jazz2/BennyCarter_LongAgoAndFarAway-2_FINAL.mid
# Parsing midi/jazz2/DonEllis_SweetAndLovely_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Soultrane_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_Serenity_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_St.Thomas-2_FINAL.mid
# Parsing midi/jazz2/ChetBaker_LongAgoAndFarAway_FINAL.mid
# Parsing midi/jazz2/JoshuaRedman_SweetSorrow_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_Cherokee_FINAL.mid
# Parsing midi/jazz2/BennyCarter_JustFriends_FINAL.mid
# Parsing midi/jazz2/JJJohnson_Walkin'_FINAL.mid
# Parsing midi/jazz2/SonnyStitt_GoodKick_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_Wow-1_FINAL.mid
# Parsing midi/jazz2/DickieWells_SixCatsAndAPrince_FINAL.mid
# Parsing midi/jazz2/KennyDorham_Doodlin'_FINAL.mid
# Parsing midi/jazz2/JJJohnson_Yesterdays_FINAL.mid
# Parsing midi/jazz2/BennyCarter_LongAgoAndFarAway-1_FINAL.mid
# Parsing midi/jazz2/SteveLacy_AskMeNow_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_MyBlueHeaven_FINAL.mid
# Parsing midi/jazz2/DonByas_HarvardBlues-2_FINAL.mid
# Parsing midi/jazz2/HerbieHancock_GingerbreadBoy_FINAL.mid
# Parsing midi/jazz2/PatMartino_AlongCameBetty_FINAL.mid
# Parsing midi/jazz2/WarneMarsh_Tautology_FINAL.mid
# Parsing midi/jazz2/WayneShorter_Orbits_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_BlueSeven-3_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Billie'sBounce_FINAL.mid
# Parsing midi/jazz2/CharlieParker_Ko=Ko_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_St.Thomas-1_FINAL.mid
# Parsing midi/jazz2/WayneShorter_E.S.P._FINAL.mid
# Parsing midi/jazz2/CharlieParker_MyLittleSuedeShoes_FINAL.mid
# Parsing midi/jazz2/MilesDavis_BluesByFive_FINAL.mid
# Parsing midi/jazz2/DonEllis_JohnnyComeLately_FINAL.mid
# Parsing midi/jazz2/BobBerg_NoMoe_FINAL.mid
# Parsing midi/jazz2/StanGetz_I'mGladThereIsYou_FINAL.mid
# Parsing midi/jazz2/PepperAdams_EarlyMorningMood_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_MaidenVoyage_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_MyHeart_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_Tautology_FINAL.mid
# Parsing midi/jazz2/SonnyRollins_BlueSeven-2_FINAL.mid
# Parsing midi/jazz2/HerbieHancock_Agitation_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_SteppingStone-1_FINAL.mid
# Parsing midi/jazz2/JohnnyHodges_Bunny_FINAL.mid
# Parsing midi/jazz2/StanGetz_MyFunnyValentine_FINAL.mid
# Parsing midi/jazz2/CharlieParker_BluesForAlice_FINAL.mid
# Parsing midi/jazz2/MilesDavis_VierdBlues_FINAL.mid
# Parsing midi/jazz2/BobBerg_BluesForBela_FINAL.mid
# Parsing midi/jazz2/CannonballAdderley_StarEyes_FINAL.mid
# Parsing midi/jazz2/DickieWells_IGotRhythm_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_TigerRag-1_FINAL.mid
# Parsing midi/jazz2/DexterGordon_SocietyRed_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_HandfulOfKeys_FINAL.mid
# Parsing midi/jazz2/DexterGordon_TheRainbowPeople_FINAL.mid
# Parsing midi/jazz2/FatsNavarro_TheSkunk_FINAL.mid
# Parsing midi/jazz2/FreddieHubbard_SocietyRed_FINAL.mid
# Parsing midi/jazz2/MilesDavis_MilesRunsTheVoodooDown-2_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Impressions_1963_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_AllTheThingsYouAre_FINAL.mid
# Parsing midi/jazz2/CannonballAdderley_HighFly_FINAL.mid
# Parsing midi/jazz2/JoeLovano_BodyAndSoul-1_FINAL.mid
# Parsing midi/jazz2/RoyEldridge_KingDavid_FINAL.mid
# Parsing midi/jazz2/BixBeiderbecke_RoyalGardenBlues_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_AprilInParis_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Oleo-1_FINAL.mid
# Parsing midi/jazz2/DonByas_Infidele(Cry)_FINAL.mid
# Parsing midi/jazz2/WayneShorter_InfantEyes_FINAL.mid
# Parsing midi/jazz2/DonByas_UnAmourPleurait_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_Groovin'High_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_WalkingShoes_FINAL.mid
# Parsing midi/jazz2/JoeHenderson_TheSidewinder_FINAL.mid
# Parsing midi/jazz2/WyntonMarsalis_You'reMyEverything_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_Jordu_FINAL.mid
# Parsing midi/jazz2/ZootSims_DancingInTheDark-1_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_HousedFromEdward-1_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_I'llRememberApril_FINAL.mid
# Parsing midi/jazz2/WoodyShaw_InACapricornianWay_FINAL.mid
# Parsing midi/jazz2/SteveColeman_Processional_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_NothingPersonal_FINAL.mid
# Parsing midi/jazz2/SteveTurre_DatDere_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Dolores_FINAL.mid
# Parsing midi/jazz2/GerryMulligan_TheRedDoor_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_George'sDilemma_FINAL.mid
# Parsing midi/jazz2/ColemanHawkins_BodyAndSoul_FINAL.mid
# Parsing midi/jazz2/LeeKonitz_I'llRememberApril_FINAL.mid
# Parsing midi/jazz2/JohnnyDodds_MuskratRamble_FINAL.mid
# Parsing midi/jazz2/DavidLiebman_Day&Nite_FINAL.mid
# Parsing midi/jazz2/SidneyBechet_I'mComingVirginia_FINAL.mid
# Parsing midi/jazz2/MilesDavis_Oleo-2_FINAL.mid
# Parsing midi/jazz2/ZootSims_DancingInTheDark-2_FINAL.mid
# Parsing midi/jazz2/DickieWells_Jo=Jo_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_UMMG_FINAL.mid
# Parsing midi/jazz2/BranfordMarsalis_HousedFromEdward-2_FINAL.mid
# Parsing midi/jazz2/JohnColtrane_Impressions_1961_FINAL.mid
# Parsing midi/jazz2/JJJohnson_MyFunnyValentine_FINAL.mid
# Parsing midi/jazz2/BennyGoodman_TigerRag-2_FINAL.mid
# Parsing midi/jazz2/DexterGordon_Dextivity_FINAL.mid
# Parsing midi/jazz2/PepperAdams_You'dBeSoNiceToComeHomeTo_FINAL.mid
# Parsing midi/jazz2/BenWebster_NightAndDay_FINAL.mid
# Parsing midi/jazz2/DizzyGillespie_Be=Bop_FINAL.mid
# Parsing midi/jazz2/LionelHampton_Dinah_FINAL.mid
# Parsing midi/jazz2/CliffordBrown_Daahoud_FINAL.mid
# Parsing midi/jazz2/JoeLovano_BodyAndSoul-2_FINAL.mid
# Parsing midi/jazz2/MilesDavis_MilesRunsTheVoodooDown-1_FINAL.mid
# Parsing midi/jazz2/MichaelBrecker_Peep_FINAL.mid
# notes ['B-4', 'B4', 'A4', 'B-4', 'E-5', 'E5', 'C#5', 'D5', 'C#5', 'B4', 'B-4', 'F#4', 'G#4', 'F4', 'F4', 'F4', 'F4', 'G4', 'D4', 'F4', 'D4', 'C#4', 'G4', 'D4', 'C4', 'G#4', 'D4', 'C4', 'G#4', 'A4', 'F4', 'C4', 'A3', 'G3', 'B-3', 'F#4', 'E4', 'C4', 'C#4', 'D4', 'D4', 'E4', 'F4', 'A4', 'E5', 'B-4', 'B4', 'A4', 'G4', 'B-4', 'C4', 'C#4', 'D4', 'B-3', 'C4', 'B-4', 'A4', 'G#4', 'A4', 'G4', 'F4', 'C#4', 'B-4', 'C5', 'D5', 'B-4', 'C5', 'A4', 'B-4', 'B-4', 'C5', 'A4', 'G4', 'F4', 'G4', 'A4', 'B-4', 'C5', 'C#5', 'D5', 'C5', 'B-4', 'G#4', 'G4', 'C#4', 'F#4', 'G4', 'G#4', 'F4', 'E-4', 'D5', 'C#5', 'B4', 'C5', 'B-4', 'B4', 'C5', 'G4', 'G4', 'E4', 'G4', 'F#4', 'D4', 'B-3', 'E4', 'F4', 'G4', 'E4', 'F4', 'G4', 'A4', 'B-4', 'C5', 'G4', 'G#4', 'F#4', 'D4', 'B-3', 'C#4', 'D4', 'B3', 'B4', 'C5', 'F#5', 'C5', 'A4', 'G4', 'B-4', 'D5', 'C4', 'A4', 'G4', 'E5', 'G5', 'F#5', 'G#5', 'E5', 'D5', 'C5', 'A4', 'B-4', 'A4', 'F4', 'E5', 'G5', 'E5', 'D5', 'C5', 'E5', 'F5', 'C5', 'A4', 'B-4', 'G4', 'F4', 'D4', 'A4', 'C5', 'B-4', 'B-4', 'A4', 'F4', 'G4', 'A4', 'B-4', 'C5', 'B4', 'C5', 'B-4', 'B-4', 'G4', 'G#4', 'E-5', 'C5', 'C#5', 'C5', 'B4', 'G#4', 'E-4', 'C4', 'G#4', 'G#4', 'A4', 'C4', 'D4', 'C4', 'E4', 'F4', 'D4', 'E4', 'F4', 'D4', 'F#4', 'G4', 'G#4', 'A4', 'B-4', 'B4', 'C5', 'A4', 'B-4', 'G#4', 'A4', 'F4', 'D4', 'C4', 'F#4', 'G4', 'E-4', 'C4', 'C#4', 'D4', 'C5', 'D5', 'C#5', 'C5', 'B4', 'C5', 'A4', 'C4', 'C5', 'D5', 'F5', 'F#5', 'F5', 'E5', 'C5', 'F5', 'B4', 'B-4', 'G#4', 'A4', 'D5', 'B4', 'A4', 'G4', 'D5', 'D5', 'G4', 'A4', 'D5', 'G4', 'D5', 'E-5', 'E5', 'E-5', 'E5', 'D5', 'E-5', 'G4', 'F#4', 'G4', 'F#4', 'G4', 'F5', 'G5', 'F#5', 'E5', 'C#5', 'D5', 'B4', 'D4', 'B4', 'C5', 'A4', 'G4', 'G#4', 'G5', 'G#5', 'B4', 'C5', 'A4', 'B-4', 'C5', 'C4', 'D4', 'E4', 'F4', 'G4', 'D4', 'G#4', 'A4', 'D4', 'C#4', 'D4', 'E4', 'B4', 'C#5', 'G#4', 'A4', 'B-4', 'B4', 'B4', 'A4', 'G4', 'G#4', 'C4', 'C#4', 'C4', 'B3', 'B-3', 'A3', 'B-3', 'C4', 'D4', 'D4', 'E4', 'G4', 'F4', 'D4', 'B-3', 'G3', 'A3', 'F3', 'D4', 'E-4', 'D4', 'B-3', 'C#4', 'B4', 'E-4', 'C4', 'B-4', 'A4', 'G4', 'G#4', 'G4', 'C4', 'F#4', 'D4', 'F#4', 'F4', 'C#4', 'C4', 'B-4', 'D4', 'C4', 'B-4', 'G#4', 'A4', 'B-3', 'G4', 'F4', 'E4', 'F4', 'F4', 'F#4', 'G#4', 'A4', 'B-4', 'B4', 'B4', 'A4', 'B-4', 'G4', 'G#4', 'C4', 'G4', 'F4', 'D4', 'E-4', 'G4', 'B-4', 'D5', 'C5', 'C#5', 'B4', 'B-4', 'G#4', 'A4', 'D5', 'E5', 'F5', 'F5', 'D5', 'C5', 'G4', 'D4', 'C4', 'G#4', 'A4', 'F4', 'C4', 'B3', 'G4', 'E4', 'F4', 'C#4', 'B-3', 'C4', 'C#4', 'E-4', 'F#4', 'G#4', 'F#4', 'C#4', 'B-4', 'C5', 'F#4', 'G#4', 'F#4', 'E-4', 'B-3', 'C#4', 'C#4', 'F#4', 'C#4', 'B3', 'C#5', 'B4', 'C#5', 'G#4', 'E-4', 'E-4', 'C4', 'G#4', 'F#4', 'G#4', 'F#4', 'E4', 'C#5', 'D5', 'B-4', 'F#4', 'A4', 'F4', 'E-4', 'F4', 'B-4', 'C5', 'E-5', 'C5', 'D5', 'A4', 'F4', 'D4', 'G4', 'B-4', 'E-4', 'G#4', 'E-4', 'C4', 'G4', 'C#4', 'G#4', 'A4', 'G4', 'F4', 'E-4', 'C4', 'C#4', 'D4', 'G4', 'B-4', 'G#4', 'A4', 'A4', 'B4', 'C5', 'C#5', 'D5', 'G4', 'F#4', 'E-4', 'F4', 'C#5', 'F5', 'E5', 'G5', 'F5', 'E5', 'D5', 'E5', 'F5', 'C5', 'D5', 'C5', 'A4', 'B-4', 'B4', 'C5', 'D5', 'C#5', 'C5', 'B4', 'B-4', 'B4', 'B-4', 'G4', 'G#4', 'D5', 'C4', 'G4', 'D5', 'E-5', 'C#5', 'B4', 'A4', 'C5', 'B4', 'A4', 'A4', 'B-4', 'G4', 'G#4', 'D5', 'B4', 'C5', 'C5', 'B4', 'C5', 'E4', 'E4', 'E4', 'A4', 'G4', 'D4', 'E4', 'C4', 'D4', 'E4', 'F4', 'E4', 'C4', 'E4', 'E4', 'C#4', 'D4', 'C4', 'E-4', 'C#4', 'D4', 'D4', 'C4', 'E-4', 'D4', 'B3', 'D4', 'B3', 'D4', 'G4', 'B-4', 'B-4', 'B4', 'D4', 'B3', 'C4', 'G4', 'A4', 'C5', 'B4', 'E-4', 'C4', 'B-4', 'G4', 'A4', 'C5', 'C#5', 'C5', 'B4', 'G4', 'B-4', 'F4', 'G#4', 'F4', 'G#4', 'B-4', 'B4', 'C5', 'C5', 'G#4', 'F4', 'F4', 'G#4', 'B-4', 'B4', 'C5', 'E-5', 'F5', 'C5', 'F4', 'G4', 'G4', 'G#4', 'G4', 'G#4', 'G4', 'F4', 'G4', 'F#4', 'G4', 'E-4', 'C4', 'G#4', 'A4', 'F4', 'C4', 'G3', 'B-3', 'G4', 'E4', 'F4', 'E3', 'F3', 'A3', 'A3', 'C4', 'C4', 'A3', 'B-3', 'B-3', 'B-3', 'D4', 'B3', 'C4', 'A4', 'F4', 'G4', 'D4', 'C4', 'B-4', 'G#4', 'C4', 'F4', 'C5', 'B-4', 'G4', 'D5', 'C5', 'B-4', 'F5', 'F5', ...

# %%
def train_network():
    """ Train a Neural Network to generate music """
    network_input, network_output, network_input2, network_output2 = prepare_sequences(notes, durations, n_vocab, d_vocab)
    
    notes_in = Input(shape = (None,))
    durations_in = Input(shape = (None,))
    #model = create_network(network_input2, d_vocab)
    model, att_model = create_network(notes_in, durations_in, n_vocab, d_vocab)

 
    checkpoint = ModelCheckpoint(
        "weights2-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5",
        monitor='loss',
        verbose=0,
        save_best_only=True,
        mode='min'
    ) 
    
    callbacks_list = [checkpoint]

    # Your line of code here
    #model.fit(network_input2, network_output2, epochs=5, callbacks=callbacks_list)
    model.fit([network_input, network_input2], [network_output, network_output2], batch_size=64, epochs=200, callbacks=callbacks_list)
    #model.summary()


train_network()
print("Finished Training")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# KerasTensor(type_spec=TensorSpec(shape=(None, 116), dtype=tf.float32, name=None), name='pitch/Softmax:0', description="created by layer 'pitch'")
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f60eb795e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f60eb795e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f60eb795950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f60eb795950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f60eb795680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f60eb795680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f60eaa9ac20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f60eaa9ac20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.step_function.<locals>.run_step at 0x7f60e9b5fb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.step_function.<locals>.run_step at 0x7f60e9b5fb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method LossFunctionWrapper.call of <keras.losses.LossFunctionWrapper object at 0x7f60e9ff2dd0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method LossFunctionWrapper.call of <keras.losses.LossFunctionWrapper object at 0x7f60e9ff2dd0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method Reduce.update_state of <keras.metrics.Mean object at 0x7f60e9519490>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Reduce.update_state of <keras.metrics.Mean object at 0x7f60e9519490>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method Reduce.result of <keras.metrics.Mean object at 0x7f60e906db50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Reduce.result of <keras.metrics.Mean object at 0x7f60e906db50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.step_function.<locals>.run_step at 0x7f60ea89ce60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.step_function.<locals>.run_step at 0x7f60ea89ce60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3076/3076 [==============================] - 1078s 350ms/step - loss: 5.0587 - pitch_loss: 3.4117 - duration_loss: 1.6469
# Epoch 2/200
# /home/dcuglian/.local/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 3076/3076 [==============================] - 1021s 332ms/step - loss: 5.0105 - pitch_loss: 3.3867 - duration_loss: 1.6238
# Epoch 3/200
#   67/3076 [..............................] - ETA: 18:00 - loss: 4.9476 - pitch_loss: 3.3666 - duration_loss: 1.5810

# %%
def prepare_sequences_prediction(notes, pitchnames, durations, durationnames, n_vocab, d_vocab):

    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    duration_to_int = dict((dur, number) for number, dur in enumerate(durationnames))
    sequence_length = 32
    network_input = []
    network_input2 = []
    output = []
    output2 = []
    
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        output.append(note_to_int[sequence_out])
        
    for i in range(0, len(durations) - sequence_length, 1):
        sequence_in = durations[i:i + sequence_length]
        sequence_out = durations[i + sequence_length]
        network_input2.append([duration_to_int[char] for char in sequence_in])
        output2.append(duration_to_int[sequence_out])
 
    n_patterns = len(network_input)
    n_patterns2 = len(network_input2)

    # reshape the input into a format compatible with LSTM layers
    normalized_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    normalized_input2 = np.reshape(network_input2, (n_patterns2, sequence_length, 1))
    # normalize input
    normalized_input = normalized_input / float(n_vocab)
    normalized_input2 = normalized_input2 / float(n_vocab)

    return (network_input, normalized_input, network_input2, normalized_input2)

def generate_notes(model, network_input, network_input2, pitchnames, durationnames, n_vocab, d_vocab):
    """ Generate notes from the neural network based on a sequence of notes """
    import random
    # Starts the melody by picking a random sequence from the input as a starting point
    start = np.random.randint(0, len(network_input)-1)
    start2 = np.random.randint(0, len(network_input2)-1)

    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
    int_to_duration = dict((number, dur) for number, dur in enumerate(durationnames))

    pattern = network_input[start]
    pattern2 = network_input2[start]
    prediction_output = []
    prediction_output2 = []

    for note_index in range(200):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input2 = np.reshape(pattern2, (1, len(pattern2), 1))
        prediction_input = prediction_input / float(n_vocab)
        prediction_input2 = prediction_input2 / float(d_vocab)
        
        ### Copy the line below from your above implementation.
        model.summary()
        prediction, prediction2 = model.predict([prediction_input, prediction_input2])
        print("prediction",prediction[0])
        
        
        indices = list(np.nonzero(prediction[0])[0])
        indices2 = list(np.nonzero(prediction2[0])[0])
        probs = prediction[0]
        probs2 = prediction2[0]
        index = random.choices(indices, weights=probs, k=1)
        index2 = random.choices(indices2, weights=probs2, k=1)
        index = index[0]
        index2 = index2[0]

#         index = np.argmax(prediction)
#         index2 = np.argmax(prediction2)
        result = int_to_note[index]
        result2 = int_to_duration[index2]
        prediction_output.append(result)
        prediction_output2.append(result2)

        pattern.append(index)
        pattern2.append(index2)
        pattern = pattern[1:len(pattern)]
        pattern2 = pattern2[1:len(pattern2)]

    return prediction_output, prediction_output2

# %%
def generate():
    notes = pickle.load(open('notes.p', 'rb'))
    durations = pickle.load(open('durations.p', 'rb'))
    
    pitchnames = sorted(set(item for item in notes))
    durationnames = sorted(set(item for item in durations))
    
    n_vocab = len(set(notes))
    d_vocab = len(set(durations))

    network_input, normalized_input, network_input2, normalized_input2 = prepare_sequences_prediction(notes, pitchnames, durations, durationnames, n_vocab, d_vocab)
    
    notes_in = Input(shape = (None,))
    durations_in = Input(shape = (None,))
    model = create_network(notes_in, durations_in, n_vocab, d_vocab)
    
    ### Add a line to load the weights here
    model.load_weights("weights2-improvement-02-5.0117-bigger.hdf5")
    
    

    prediction_output, prediction_output2 = generate_notes(model, network_input, network_input2, pitchnames, durationnames, n_vocab, d_vocab)
    create_midi(prediction_output, prediction_output2)

# %%
def create_midi(prediction_output, prediction_output2):
    offset = 0
    output_notes = []
    for pattern, pattern2 in zip(prediction_output, prediction_output2):
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Saxophone()
                notes.append(new_note)
            print("patern2:", pattern2)
            d = duration.Duration(pattern2)
            new_chord = chord.Chord(notes, duration=d)
            new_chord.offset = offset
            output_notes.append(new_chord)
        elif pattern == 'rest':
            new_note = note.Rest()
            new_note.duration = duration.Duration(pattern2)
            new_note.storedInstrument = instrument.Saxophone()
            output_notes.append(new_note)
        else:
            d = duration.Duration(pattern2)
            new_note = note.Note(pattern, duration=d)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Saxophone()
            output_notes.append(new_note)
        offset += 0.5
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='test_output.mid')
    
generate()
print("done")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 116), dtype=tf.float32, name=None), name='pitch/Softmax:0', description="created by layer 'pitch'")
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f81623f4200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f81623f4200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f81623f4950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f81623f4950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f81623f4dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f81623f4dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f83d2e217a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f83d2e217a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.step_function.<locals>.run_step at 0x7f8131422050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.step_function.<locals>.run_step at 0x7f8131422050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d37199e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d37199e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d3719dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d3719dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d3719ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d3719ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f813154aa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f813154aa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f813154acb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f813154acb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f813154ad40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f813154ad40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d2b455f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d2b455f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f813154a8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f813154a8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d2b459e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d2b459e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d2fdd3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d2fdd3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d2fdd0e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d2fdd0e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d2b45950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f83d2b45950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ...
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f8162e69710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f8162e69710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f8131541e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f8131541e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f81314227a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f81314227a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, None, 100)    11600       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 100)    7000        input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, 200)    0           embedding_14[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, None, 256)    467968      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, None, 256)    525312      lstm_14[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 1)      257         lstm_15[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, None)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None)         0           reshape_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 256, None)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, None, 256)    0           repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 256)    0           lstm_15[0][0]
#                                                                  permute_7[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256)          0           multiply_7[0][0]
# __________________________________________________________________________________________________
# pitch (Dense)                   (None, 116)          29812       lambda_7[0][0]
# __________________________________________________________________________________________________
# duration (Dense)                (None, 70)           17990       lambda_7[0][0]
# ==================================================================================================
# Total params: 1,059,939
# Trainable params: 1,059,939
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d5874b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.permutation at 0x7f83d5874b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d34295f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices at 0x7f83d34295f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f8162f19950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch at 0x7f8162f19950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# prediction [4.93174548e-06 2.38181792e-06 1.90461492e-06 2.61795412e-06
#  3.85672593e-06 1.41135672e-06 1.45185516e-06 1.65228391e-06
#  6.41106226e-06 1.44637022e-06 1.62972196e-06 4.89595732e-06
#  1.38750534e-06 2.28408885e-06 2.11115002e-06 3.08150788e-06
#  1.68574672e-06 2.87562239e-06 2.48220340e-06 1.99166311e-06
#  1.93721871e-06 1.39457347e-06 1.31526940e-06 7.39331608e-06
#  1.84727344e-06 1.80102074e-06 1.45663444e-06 1.51913594e-06
#  1.29337980e-06 1.53074416e-06 2.34432559e-06 2.83139889e-06
#  2.14938927e-06 2.94995357e-06 1.38844109e-06 1.85550311e-06
#  1.36738470e-06 3.29457225e-06 2.04454636e-06 6.36602590e-06
#  3.32417608e-06 3.58280931e-06 3.70100588e-06 1.77406594e-06
#  2.50901644e-06 2.40011855e-06 1.50151197e-06 1.45613160e-06
#  3.39300959e-06 2.76081323e-06 4.52610311e-06 1.16377277e-03
#  2.41956767e-02 4.95761409e-02 6.58461452e-03 1.46250704e-06
#  2.24498496e-03 3.93613204e-02 5.77251352e-02 7.56152533e-03
#  1.57238594e-06 1.16870087e-03 2.18414105e-02 3.20853703e-02
#  4.56476817e-03 1.29404111e-06 1.42598333e-06 3.78319644e-03
#  3.27904895e-02 2.58336794e-02 2.06050510e-03 1.34026584e-06
#  1.38131190e-06 3.80821247e-03 4.42806184e-02 4.38455716e-02
#  4.72746557e-03 1.35750986e-06 1.57427507e-06 7.95597024e-03
#  5.02113551e-02 3.04042250e-02 1.77624309e-03 1.35141033e-06
#  1.56428393e-06 1.07566118e-02 5.34418449e-02 2.68026926e-02
#  8.32159189e-04 1.44612329e-06 8.62440374e-03 4.16468158e-02
#  1.51376715e-02 1.65342368e-04 1.89082959e-06 3.12111024e-06
#  1.10627841e-02 3.53023596e-02 9.14089940e-03 5.13997729e-05
#  4.32525167e-06 1.96178686e-02 7.06237257e-02 1.98772158e-02
#  1.82763804e-04 1.52376026e-06 4.74884000e-04 1.93705838e-02
#  4.81003858e-02 9.70299821e-03 3.03519482e-06 5.65317714e-05
#  2.54361536e-02 6.01920262e-02 1.36769479e-02 1.07758478e-05]
# done
